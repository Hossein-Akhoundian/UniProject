# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../Dataset/results.csv")

df = df.dropna()

df["date"] = pd.to_datetime(df["date"])

df["Year"] = df["date"].dt.year

bins = [1872,1892,1912,1932,1952,1972,1992,2012,2032]

labels=[
"1872-1891",
"1892-1911",
"1912-1931",
"1932-1951",
"1952-1971",
"1972-1991",
"1992-2011",
"2012-2031"
]

df["Era"]=pd.cut(df["Year"],bins=bins,labels=labels,right=False)

df["Goal_Diff"]=df["home_score"]-df["away_score"]

# df["Home_Win"]=(df["home_score"]>df["away_score"]).astype(int)

df["Home_Win"] = np.where(
    df["home_score"] > df["away_score"],
    "Win",
    "NotWin"
)

df["Match_Type"]=np.where(
df["tournament"]=="Friendly",
"Friendly",
"Official"
)

df["Neutral"]=df["neutral"].astype(int)

# %%
rapidminer_df = df[
    [
        "Year",
        "Era",
        "Match_Type",
        "Neutral",
        "Home_Win"
    ]
]

rapidminer_df.head()
# Out:
#    Year        Era Match_Type  Neutral Home_Win
# 0  1872  1872-1891   Friendly        0   NotWin
# 1  1873  1872-1891   Friendly        0      Win
# 2  1874  1872-1891   Friendly        0      Win
# 3  1875  1872-1891   Friendly        0   NotWin
# 4  1876  1872-1891   Friendly        0      Win

# %%
rapidminer_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49487 entries, 0 to 49486
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        49487 non-null  int32
#  1   Era         49487 non-null  category
#  2   Match_Type  49487 non-null  str
#  3   Neutral     49487 non-null  int64
#  4   Home_Win    49487 non-null  str
# dtypes: category(1), int32(1), int64(1), str(2)
# memory usage: 1.4 MB

# %%
rapidminer_df.to_csv(
    "../Output/final_dataset2.csv",
    index=False
)

print("Dataset Saved Successfully")
# Out:
# Dataset Saved Successfully
